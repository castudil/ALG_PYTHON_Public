# %% [markdown]
# # Algoritmos y Estructuras de Datos
# ## Semana 3 · Unidad 1 — Introducción y Conceptos Fundamentales
#
# Este documento unifica el marco teórico, la formalización matemática y la implementación práctica en Python.

# %% [markdown]
# ## 🎯 Objetivos de Aprendizaje
#
# Al finalizar esta sesión, el estudiante será capaz de:
#
# 1. **Comprender** por qué se cuenta el número de operaciones en vez de medir segundos.
# 2. **Identificar** las notaciones asintóticas $O$, $\Omega$ y $\Theta$ y qué afirma cada una.
# 3. **Implementar** el conteo de operaciones de un algoritmo iterativo para derivar su $T(n)$.
# 4. **Analizar** el caso peor, el mejor y el promedio, y reconocer cuál es el relevante en cada situación.
# 5. **Resolver** la comparación de órdenes de crecimiento típicos: $\log n$, $n$, $n\log n$, $n^2$ y $2^n$.

# %% [markdown]
# ### 1. Evolución del Método Científico
# El método científico es un proceso iterativo de observación, hipótesis, experimentación y revisión, desarrollado a través de cuatro etapas clave:
# * **Antecedentes Antiguos:** Pensamiento empírico en Egipto (c. 1600 a.C.) y razonamiento deductivo de Aristóteles.
# * **Edad de Oro del Islam:** Alhacén (1021 d.C.) y la necesidad de pruebas experimentales reproducibles combinadas con lógica matemática.
# * **Renacimiento:** Francis Bacon (1620) y la formalización del método inductivo.
# * **Revolución Científica:** Galileo, Descartes y Newton consolidan la matematización, el análisis racional y el modelo de leyes universales.

# %% [markdown]
# ### 2. Taxonomía de Problemas Computacionales
# Clasificación estructurada bajo la Teoría de la Computabilidad y Complejidad.
#
# **Según la Naturaleza del Resultado:**
# * **De Decisión:** Respuesta binaria (Sí/No).
# * **De Búsqueda:** Localización de una estructura o valor.
# * **De Optimización:** Búsqueda de la mejor solución (minimizar/maximizar).
# * **De Conteo:** Cálculo de la cardinalidad de soluciones válidas.
#
# **Según Computabilidad:**
# * **Decidibles:** Existe un algoritmo que siempre se detiene.
# * **Indecidibles:** No existe un algoritmo general (ej. Problema de la Parada).
#
# **Según Complejidad Computacional:**
# * **P:** Resolubles en tiempo polinómico determinista $\mathcal{O}(n^k)$.
# * **NP:** Soluciones verificables en tiempo polinómico determinista.
# * **NP-Completo:** Los problemas más difíciles de NP.
# * **NP-Hard:** Al menos tan difíciles como los NP-Completos, no restringidos a decisión.

# %% [markdown]
# > 🎙️ **[PAUSA PROFESOR]** Pregunta sugerida: *"¿Es correcto decir que la búsqueda binaria es $O(n^2)$?"* — Sí lo es, y por eso $O$ sola dice poco: es una cota superior, no una descripción exacta. Ahí entra $\Theta$.

# %% [markdown]
# ### 3. Problemas de Conteo (Clase #P)
# Buscan determinar la cantidad exacta de soluciones válidas.
# 1. **Conteo de Caminos Simples:** Calcular el número total de rutas distintas entre dos nodos en un grafo sin repetir nodos.
# 2. **Conteo de Coloraciones:** Calcular las formas de asignar $k$ colores a los nodos de un grafo sin que nodos adyacentes compartan color.
# 3. **Conteo de Satisfacibilidad (#SAT):** Calcular las asignaciones de valores booleanos que hacen verdadera una fórmula lógica.

# %% [markdown]
# ### 4. Importancia de Algoritmos y Estructuras de Datos
# Núcleo fundacional de la ciencia de la computación basado en:
# 1. **Eficiencia y Análisis de Complejidad:** Evaluación asintótica de recursos (tiempo/memoria) usando notación $\mathcal{O}$.
# 2. **Abstracción y Modelado:** Traducción de problemas reales a representaciones lógicas. La topología de datos dicta los límites de eficiencia.
# 3. **Prerrequisito Arquitectónico:** Sustrato lógico para arquitecturas avanzadas (ej. modelos de inteligencia artificial y procesamiento de tensores).

# %% [markdown]
# ### 5. Cronología de Algoritmos Fundamentales
# * **c. 300 a.C. - Euclides:** Máximo común divisor.
# * **c. 240 a.C. - Eratóstenes:** Generación de números primos.
# * **1956 - Dijkstra:** Camino más corto en grafos.
# * **1959 - Quicksort:** Ordenamiento en $\mathcal{O}(n \log n)$.
# * **1965 - FFT:** Transformada rápida de Fourier.
# * **1977 - RSA:** Criptografía asimétrica.
# * **1986 - Backpropagation:** Entrenamiento de redes neuronales.
# * **1998 - PageRank:** Análisis de centralidad de grafos.
# * **2017 - Transformers (Self-Attention):** Procesamiento paralelo de secuencias.

# %% [markdown]
# ### 6. Contraste Práctico: Implementación en Python
# Relación directa entre una estructura de datos (arreglo dinámico) y la ejecución de un algoritmo de búsqueda lineal.

# %%
# Estructura de Datos: Lista (Arreglo dinámico en memoria)
temperaturas = [15.5, 18.2, 14.1, 22.0, 19.3]

# Algoritmo: Búsqueda lineal del valor máximo
max_temp = temperaturas[0]
for temp in temperaturas:
    if temp > max_temp:
        max_temp = temp

print(f"Temperatura máxima: {max_temp}")

# Análisis de Complejidad:
# Tiempo: O(n) - Itera sobre todos los elementos una vez.
# Espacio: O(1) - Utiliza una variable extra independiente del tamaño del arreglo.

# %% [markdown]
# ## 📚 Lecturas Recomendadas y Práctica
#
# ### Textbooks
#
# | Libro | Edición | Capítulo | Tema |
# |-------|---------|----------|------|
# | Cormen et al. (CLRS) — *Introduction to Algorithms* | 4ª ed. | Cap. 3 | Notación asintótica: O, Omega y Theta |
# | Miller & Ranum (M&R) — *Problem Solving with Algorithms and Data Structures Using Python* | 2011 | Cap. 2 | Análisis de algoritmos |
# | Goodrich, Tamassia & Goldwasser (GTG) — *Data Structures and Algorithms in Python* | 1ª ed. | Cap. 3 | Análisis de algoritmos |
# | Bhargava (Grok) — *Grokking Algorithms* | 2ª ed. | Cap. 1 | Introducción a la notación O grande |
#
# ### Recursos gratuitos en línea
#
# - 🌐 [Big-O Cheat Sheet](https://www.bigocheatsheet.com/) — tabla de costos de las estructuras y algoritmos habituales.
# - 🌐 [VisuAlgo](https://visualgo.net/en) — visualizaciones interactivas de estructuras y algoritmos.
#
# ### Práctica en Codeforces (soporta Python 3)
#
# > 🔍 **Cómo filtrar:** ve a [codeforces.com/problemset](https://codeforces.com/problemset),
# > escribe la etiqueta en **Tags** y ajusta **Rating**.
#
# **Escala de dificultad orientativa para este curso:**
#
# | Rating | Nivel | Descripción |
# |--------|-------|-------------|
# | 800 | ⭐ | Aplicación directa — la mayoría puede resolverlo |
# | 1000–1200 | ⭐⭐ | Requiere una pequeña adaptación |
# | 1300+ | ⭐⭐⭐ | Combina la idea con otra — desafío |
#
# **Problemas recomendados para este tópico:**
#
# | # | Problema | Rating | Por qué es útil |
# |---|----------|--------|-----------------|
# | 1 | [4A — Watermelon](https://codeforces.com/problemset/problem/4/A) | ⭐ 800 | O(1): la solución de fuerza bruta y la fórmula cerrada |
# | 2 | [50A — Domino piling](https://codeforces.com/problemset/problem/50/A) | ⭐ 800 | Contrasta el conteo directo con simular la colocación |
# | 3 | [486A — Calculating Function](https://codeforces.com/problemset/problem/486/A) | ⭐⭐ 800 | La versión O(n) da TLE; hay que hallar la fórmula O(1) |
# | 4 | [479A — Expression](https://codeforces.com/problemset/problem/479/A) | ⭐⭐ 1000 | Espacio de búsqueda pequeño: la fuerza bruta es aceptable y hay que argumentarlo |
#
# ⚠️ Los dos primeros son el **mínimo esperado**. Los demás son desafío opcional.

# %% [markdown]
# ## 🧪 Ejercicio 1: Contar operaciones ⭐
#
# **Descripción:** cuenta **exactamente** cuántas veces se ejecuta la operación interna de
# este bucle anidado, sin ejecutarlo:
#
# ```python
# for i in range(n):
#     for j in range(i, n):
#         operacion()      # <- contar estas
# ```
#
# **Entrada:** `n` (int), el tamaño del problema.
# **Salida:** el número exacto de ejecuciones de `operacion()`.
#
# **Ejemplo:**
# ```
# Entrada: n = 4
# Salida:  10      (4 + 3 + 2 + 1)
# ```
#
# **Restricciones:** $0 \le n \le 10^6$. Debe responder en $O(1)$, sin bucles.
# **Complejidad esperada:** O(1)
#
# > 💡 **Pista:** para cada `i`, el bucle interno hace `n - i` iteraciones. Suma
# > $n + (n-1) + \dots + 1$.

# %%
def contar_operaciones(n):
    """
    Número exacto de ejecuciones del cuerpo del bucle anidado.

    Parámetros:
        n (int): tamaño del problema
    Retorna:
        int: número de ejecuciones
    """
    # Tu código aquí
    pass

# %%
def verificar_ejercicio_1(fn):
    """Compara contra el conteo real, simulando el bucle."""
    import time
    def real(n):
        return sum(1 for i in range(n) for _ in range(i, n))
    casos = [(0,"n = 0"),(1,"n = 1"),(4,"el ejemplo del enunciado"),
             (10,"n = 10"),(100,"n = 100"),(10**6,"n = 10^6: debe ser O(1), no simular")]
    aprobados=0
    for n,desc in casos:
        esperado = real(n) if n<=1000 else n*(n+1)//2
        t0=time.perf_counter()
        try:
            r=fn(n); t1=time.perf_counter()
            lento=(t1-t0)>0.5
            if r==esperado and not lento:
                print(f"  ✅ {desc} ({(t1-t0)*1000:.2f}ms) -> {r}"); aprobados+=1
            elif lento:
                print(f"  ❌ {desc} — demasiado lento ({t1-t0:.2f}s): ¿estás simulando el bucle?")
            else:
                print(f"  ❌ {desc}\n     Esperado: {esperado}\n     Obtenido: {r}")
        except Exception as e:
            print(f"  💥 {desc} — Error: {e}")
    print(f"\n{'🎉 Todos los casos pasaron!' if aprobados==len(casos) else f'⚠️  {aprobados}/{len(casos)} casos correctos'}")

verificar_ejercicio_1(contar_operaciones)

# %%
# ═══════════════════════════════════════════════════
# SOLUCIÓN — Descomenta para ver después de intentarlo
# ═══════════════════════════════════════════════════

# def contar_operaciones(n):
#     """Suma de Gauss: n + (n-1) + ... + 1 = n(n+1)/2."""
#     # Paso 1: para cada i, el bucle interno hace n - i iteraciones
#     # Paso 2: la suma total es n + (n-1) + ... + 1
#     # Paso 3: fórmula cerrada de Gauss, en O(1)
#     return n * (n + 1) // 2
#     # Complejidad: O(1) temporal y espacial
#     # Nota: T(n) = n(n+1)/2 = Theta(n^2), aunque el bucle interno no sea completo

# %% [markdown]
# ## 🧪 Ejercicio 2: ¿Cuál crece más rápido? ⭐⭐
#
# **Descripción:** dadas dos funciones de costo, encuentra el **menor** $n \ge 1$ a partir del
# cual la primera supera a la segunda **y no la vuelve a cruzar** en el rango examinado.
#
# Es la pregunta práctica detrás de la notación asintótica: un algoritmo $O(n^2)$ puede ser
# más rápido que uno $O(n\log n)$ para $n$ pequeño, y aquí se ve dónde está el cruce.
#
# **Entrada:**
# - `f`, `g` (callable): reciben un entero `n` y devuelven un costo
# - `tope` (int): hasta qué `n` buscar
#
# **Salida:** el menor `n` tal que `f(k) > g(k)` para todo `k` entre `n` y `tope`;
# `None` si no existe.
#
# **Ejemplo:**
# ```
# Entrada: f = lambda n: n**2, g = lambda n: 100*n, tope = 500
# Salida:  101      (a partir de 101, n² supera siempre a 100n)
# ```
#
# **Restricciones:** $1 \le$ tope $\le 10^4$.
# **Complejidad esperada:** O(tope)
#
# > 💡 **Pista:** recorre desde `tope` hacia abajo y recuerda el último punto donde
# > la desigualdad se rompió.

# %%
def punto_de_cruce(f, g, tope):
    """
    Menor n desde el cual f supera a g y ya no la vuelve a cruzar hasta `tope`.

    Parámetros:
        f, g (callable): funciones de costo
        tope (int): límite superior de búsqueda
    Retorna:
        int | None: el punto de cruce, o None si f nunca domina
    """
    # Tu código aquí
    pass

# %%
def verificar_ejercicio_2(fn):
    """Casos con cruces conocidos analíticamente."""
    import math, time
    casos = [
        ((lambda n: n**2, lambda n: 100*n, 500), 101, "n² supera a 100n en 101"),
        ((lambda n: n, lambda n: 1, 100), 2, "n supera a 1 desde n=2"),
        ((lambda n: n, lambda n: n**2, 100), None, "n nunca supera a n²"),
        ((lambda n: 2**n, lambda n: n**3, 30), 10, "2^n supera a n³ en n=10"),
        ((lambda n: n*math.log2(n) if n>1 else 0, lambda n: n, 1000), 3, "n·log₂n supera a n en n=3"),
        ((lambda n: 1, lambda n: 1, 50), None, "iguales: nunca hay dominancia estricta"),
    ]
    aprobados=0
    for (f,g,tope), esperado, desc in casos:
        t0=time.perf_counter()
        try:
            r=fn(f,g,tope); t1=time.perf_counter()
            if r==esperado:
                print(f"  ✅ {desc} ({(t1-t0)*1000:.2f}ms) -> {r}"); aprobados+=1
            else:
                print(f"  ❌ {desc}\n     Esperado: {esperado}\n     Obtenido: {r}")
        except Exception as e:
            print(f"  💥 {desc} — Error: {e}")
    print(f"\n{'🎉 Todos los casos pasaron!' if aprobados==len(casos) else f'⚠️  {aprobados}/{len(casos)} casos correctos'}")

verificar_ejercicio_2(punto_de_cruce)

# %%
# ═══════════════════════════════════════════════════
# SOLUCIÓN — Descomenta para ver después de intentarlo
# ═══════════════════════════════════════════════════

# def punto_de_cruce(f, g, tope):
#     """Recorre de `tope` hacia abajo buscando la última vez que f NO domina."""
#     # Paso 1: si en el tope f no domina, no hay cruce estable
#     if f(tope) <= g(tope):
#         return None
#     # Paso 2: bajar mientras f siga dominando; el primer fallo marca la frontera
#     cruce = 1
#     for n in range(tope, 0, -1):
#         if f(n) <= g(n):
#             cruce = n + 1
#             break
#     # Paso 3: si nunca falló, f domina desde n=1
#     return cruce
#     # Complejidad: O(tope) temporal, O(1) espacial
